# %%
import seaborn as sns
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.scatterplot(x="total_bill",y="tip",data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# inference = from the plot we can say as bill amount increase the tip also increases

# %%
sns.scatterplot(x="size",y="total_bill",data = df)
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.scatterplot(x="size",y="tip",data = df)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
df.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
sns.lineplot(x='size',y='tip',data=df,ci=None)
# Out:
# <ipython-input-25-227da49031e2>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='size',y='tip',data=df,ci=None)
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.displot(df["tip"])

# %%
sns.relplot(x="total_bill",y="tip",data=df,hue="day")

# %%
sns.barplot(x="total_bill",y="day",data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.barplot(data=df,x="tip",y="day",ci=None)
# Out:
# <ipython-input-35-e3ed181363d5>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="tip",y="day",ci=None)
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.countplot(x="sex",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.jointplot(x="total_bill",y="tip",data=df)

# %%
sns.boxplot(x="day",y="total_bill",data = df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#line distributtig the box is the median lower and upper quartiles the dots are the outliers
